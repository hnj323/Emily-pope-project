# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("BostonHousingData.csv")
dataset
# Out:
#            town  tract  longitude   latitude  ...  tax    ptratio  lstat      cmedv
# 0        Nahant   2011 -70.955002  42.255001  ...  296  15.300000   4.98  24.000000
# 1    Swampscott   2021 -70.949997  42.287498  ...  242  17.799999   9.14  21.600000
# 2    Swampscott   2022 -70.935997  42.283001  ...  242  17.799999   4.03  34.700001
# 3    Marblehead   2031 -70.928001  42.292999  ...  222  18.700001   2.94  33.400002
# 4    Marblehead   2032 -70.921997  42.298000  ...  222  18.700001   5.33  36.200001
# ..          ...    ...        ...        ...  ...  ...        ...    ...        ...
# 501    Winthrop   1801 -70.986000  42.231201  ...  273  21.000000   9.67  22.400000
# 502    Winthrop   1802 -70.990997  42.227501  ...  273  21.000000   9.08  20.600000
# 503    Winthrop   1803 -70.994797  42.226002  ...  273  21.000000   5.64  23.900000
# 504    Winthrop   1804 -70.987503  42.223999  ...  273  21.000000   6.48  22.000000
# 505    Winthrop   1805 -70.982498  42.221001  ...  273  21.000000   7.88  19.000000
#
# [506 rows x 17 columns]

# %%
X = dataset[["tract" , "longitude" , "latitude" , "crime" , "residential" , "industrial" , "nox" , "rooms" , "older" , "distance" , "highway" , "tax" , "ptratio" , "lstat"]].values

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
X.shape
# Out:
# (506, 14)

# %%
X
# Out:
# array([[2011.        ,  -70.9550018 ,   42.2550011 , ...,  296.        ,
#           15.3000002 ,    4.98000002],
#        [2021.        ,  -70.9499969 ,   42.2874985 , ...,  242.        ,
#           17.7999992 ,    9.14000034],
#        [2022.        ,  -70.935997  ,   42.2830009 , ...,  242.        ,
#           17.7999992 ,    4.03000021],
#        ...,
#        [1803.        ,  -70.9947968 ,   42.2260017 , ...,  273.        ,
#           21.        ,    5.63999987],
#        [1804.        ,  -70.9875031 ,   42.223999  , ...,  273.        ,
#           21.        ,    6.48000002],
#        [1805.        ,  -70.9824982 ,   42.2210007 , ...,  273.        ,
#           21.        ,    7.88000011]])

# %%
y = dataset[["cmedv"]].values

# %%
y
# Out:
# array([[24.        ],
#        [21.6000004 ],
#        [34.7000008 ],
#        [33.4000015 ],
#        [36.2000008 ],
#        [28.7000008 ],
#        [22.8999996 ],
#        [22.1000004 ],
#        [16.5       ],
#        [18.8999996 ],
#        [15.        ],
#        [18.8999996 ],
#        [21.7000008 ],
#        [20.3999996 ],
#        [18.2000008 ],
#        [19.8999996 ],
#        [23.1000004 ],
#        [17.5       ],
#        [20.2000008 ],
#        [18.2000008 ],
#        [13.6000004 ],
#        [19.6000004 ],
#        [15.1999998 ],
#        [14.5       ],
#        [15.6000004 ],
#        [13.8999996 ],
#        [16.6000004 ],
#        [14.8000002 ],
#        [18.3999996 ],
#        [21.        ],
#        [12.6999998 ],
#        [14.5       ],
#        [13.1999998 ],
#        [13.1000004 ],
#        [13.5       ],
#        [18.8999996 ],
#        [20.        ],
#        [21.        ],
#        [24.2000008 ],
#        [30.7999992 ],
#        [34.9000015 ],
#        [26.6000004 ],
#        [25.2999992 ],
#        [24.7000008 ],
#        [21.2000008 ],
#        [19.2999992 ],
#        [23.1000004 ],
#        [21.        ],
#        [23.7999992 ],
#        [23.1000004 ],
#        [20.3999996 ],
#        [18.5       ],
#        [25.        ],
#        [24.6000004 ],
#        [23.        ],
#        [22.2000008 ],
#        [19.2999992 ],
#        [22.6000004 ],
#        [19.7999992 ],
#        [17.1000004 ],
#        [19.3999996 ],
#        [22.2000008 ],
#        [20.7000008 ],
#        [21.1000004 ],
#        [19.5       ],
#        [18.5       ],
#        [20.6000004 ],
#        [19.        ],
#        [18.7000008 ],
#        [32.7000008 ],
#        [16.5       ],
#        [23.8999996 ],
#        [31.2000008 ],
#        [17.5       ],
#        [17.2000008 ],
#        [23.1000004 ],
#        [24.5       ],
#        [26.6000004 ],
#        [22.8999996 ],
#        [24.1000004 ],
#        [18.6000004 ],
#        [30.1000004 ],
#        [18.2000008 ],
#        [20.6000004 ],
#        [17.7999992 ],
#        [21.7000008 ],
#        [22.7000008 ],
#        [22.6000004 ],
#        [25.        ],
#        [19.8999996 ],
#        [20.7999992 ],
#        [16.7999992 ],
#        [21.8999996 ],
#        [27.5       ],
#        [21.8999996 ],
#        [23.1000004 ],
#        [50.        ],
#        [50.        ],
#        [50.        ],
#        [50.        ],
#        [50.        ],
#        [13.8000002 ],
#        [13.8000002 ],
#        [15.        ],
#        [13.8999996 ],
#        [13.3000002 ],
#        [13.1000004 ],
#        [10.1999998 ],
#        [10.3999996 ],
#        [10.8999996 ],
#        [11.3000002 ],
#        [12.3000002 ],
#        [ 8.80000019],
#        [ 7.19999981],
#        [10.5       ],
#        [ 7.4000001 ],
#        [10.1999998 ],
#        [11.5       ],
#        [15.1000004 ],
#        [23.2000008 ],
#        [ 9.69999981],
#        [13.8000002 ],
#        [12.6999998 ],
#        [13.1000004 ],
#        [12.5       ],
#        [ 8.5       ],
#        [ 5.        ],
#        [ 6.30000019],
#        [ 5.5999999 ],
#        [ 7.19999981],
#        [12.1000004 ],
#        [ 8.30000019],
#        [ 8.5       ],
#        [ 5.        ],
#        [11.8999996 ],
#        [27.8999996 ],
#        [17.2000008 ],
#        [27.5       ],
#        [15.        ],
#        [17.2000008 ],
#        [17.8999996 ],
#        [16.2999992 ],
#        [ 7.        ],
#        [ 7.19999981],
#        [ 7.5       ],
#        [10.3999996 ],
#        [ 8.80000019],
#        [ 8.39999962],
#        [16.7000008 ],
#        [14.1999998 ],
#        [20.7999992 ],
#        [13.3999996 ],
#        [11.6999998 ],
#        [ 8.30000019],
#        [10.1999998 ],
#        [10.8999996 ],
#        [11.        ],
#        [ 9.5       ],
#        [14.5       ],
#        [14.1000004 ],
#        [16.1000004 ],
#        [14.3000002 ],
#        [11.6999998 ],
#        [13.3999996 ],
#        [ 9.60000038],
#        [ 8.19999981],
#        [ 8.39999962],
#        [12.8000002 ],
#        [10.5       ],
#        [17.1000004 ],
#        [14.8000002 ],
#        [15.3999996 ],
#        [10.8000002 ],
#        [11.8000002 ],
#        [14.8999996 ],
#        [12.6000004 ],
#        [14.1000004 ],
#        [13.        ],
#        [13.3999996 ],
#        [15.1999998 ],
#        [16.1000004 ],
#        [17.7999992 ],
#        [14.3999996 ],
#        [14.1000004 ],
#        [12.6999998 ],
#        [13.5       ],
#        [14.8999996 ],
#        [20.        ],
#        [16.3999996 ],
#        [17.7000008 ],
#        [19.5       ],
#        [20.2000008 ],
#        [21.3999996 ],
#        [19.8999996 ],
#        [19.        ],
#        [19.1000004 ],
#        [19.1000004 ],
#        [20.1000004 ],
#        [19.8999996 ],
#        [19.6000004 ],
#        [23.2000008 ],
#        [29.7999992 ],
#        [13.8000002 ],
#        [13.3000002 ],
#        [16.7000008 ],
#        [12.        ],
#        [14.6000004 ],
#        [21.3999996 ],
#        [23.        ],
#        [23.7000008 ],
#        [25.        ],
#        [21.7999992 ],
#        [20.6000004 ],
#        [21.2000008 ],
#        [19.1000004 ],
#        [20.6000004 ],
#        [15.1999998 ],
#        [ 7.        ],
#        [ 8.10000038],
#        [13.6000004 ],
#        [20.1000004 ],
#        [21.7999992 ],
#        [24.5       ],
#        [23.1000004 ],
#        [19.7000008 ],
#        [18.2999992 ],
#        [21.2000008 ],
#        [17.5       ],
#        [16.7999992 ],
#        [22.3999996 ],
#        [20.6000004 ],
#        [23.8999996 ],
#        [22.        ],
#        [19.        ]])

# %%
y.shape
# Out:
# (506, 1)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression

# k-fold CV (using all the 14 variables) for 5 times
lm = LinearRegression()
# can tune other metrics, such as MSE
scores = cross_val_score(lm, X, y, scoring='neg_mean_squared_error', cv=5)
scores
# Out:
# array([-25.82783243, -27.23794898, -30.3510623 , -80.25664814,
#        -31.40953455])

# %%
""" XGBOOST """
from xgboost import XGBRegressor

my_model = XGBRegressor()
# can tune other metrics, such as MSE
scores = cross_val_score(my_model, X, y, scoring='neg_mean_squared_error', cv=5)
scores
# Out:
# [01:03:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:03:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:03:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:03:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:03:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# array([ -6.78874155,  -9.79002285, -19.71282514, -41.26469772,
#        -16.62709911])

# %% [markdown]
# It seems that the simple linear regression is better than the XGBoost as the negative MSE of the simple linear regression is less than XGBRegressor

# %%
dataset = pd.read_csv("Cars.csv")
dataset
# Out:
#       MPG  CYL    ENG   WGT
# 0    18.0    8  307.0  3504
# 1    15.0    8  350.0  3693
# 2    18.0    8  318.0  3436
# 3    16.0    8  304.0  3433
# 4    17.0    8  302.0  3449
# ..    ...  ...    ...   ...
# 387  27.0    4  140.0  2790
# 388  44.0    4   97.0  2130
# 389  32.0    4  135.0  2295
# 390  28.0    4  120.0  2625
# 391  31.0    4  119.0  2720
#
# [392 rows x 4 columns]

# %%
X = dataset[["MPG" , "CYL" , "ENG"]].values
X
# Out:
# array([[ 18.,   8., 307.],
#        [ 15.,   8., 350.],
#        [ 18.,   8., 318.],
#        ...,
#        [ 32.,   4., 135.],
#        [ 28.,   4., 120.],
#        [ 31.,   4., 119.]])

# %%
X.shape
# Out:
# (392, 3)

# %%
y = dataset[["WGT"]].values
y
# Out:
# array([[3504],
#        [3693],
#        [3436],
#        [3433],
#        [3449],
#        [4341],
#        [4354],
#        [4312],
#        [4425],
#        [3850],
#        [3563],
#        [3609],
#        [3761],
#        [3086],
#        [2372],
#        [2833],
#        [2774],
#        [2587],
#        [2130],
#        [1835],
#        [2672],
#        [2430],
#        [2375],
#        [2234],
#        [2648],
#        [4615],
#        [4376],
#        [4382],
#        [4732],
#        [2130],
#        [2264],
#        [2228],
#        [2634],
#        [3439],
#        [3329],
#        [3302],
#        [3288],
#        [4209],
#        [4464],
#        [4154],
#        [4096],
#        [4955],
#        [4746],
#        [5140],
#        [2962],
#        [2408],
#        [3282],
#        [3139],
#        [2220],
#        [2123],
#        [2074],
#        [2065],
#        [1773],
#        [1613],
#        [1834],
#        [1955],
#        [2278],
#        [2126],
#        [2254],
#        [2408],
#        [2226],
#        [4274],
#        [4385],
#        [4135],
#        [4129],
#        [3672],
#        [4633],
#        [4502],
#        [4456],
#        [4422],
#        [2330],
#        [3892],
#        [4098],
#        [4294],
#        [4077],
#        [2933],
#        [2511],
#        [2979],
#        [2189],
#        [2395],
#        [2288],
#        [2506],
#        [2164],
#        [2100],
#        [4100],
#        [3672],
#        [3988],
#        [4042],
#        [3777],
#        [4952],
#        [4464],
#        [4363],
#        [4237],
#        [4735],
#        [4951],
#        [3821],
#        [3121],
#        [3278],
#        [2945],
#        [3021],
#        [2904],
#        [1950],
#        [4997],
#        [4906],
#        [4654],
#        [4499],
#        [2789],
#        [2279],
#        [2401],
#        [2379],
#        [2124],
#        [2310],
#        [2472],
#        [2265],
#        [4082],
#        [4278],
#        [1867],
#        [2158],
#        [2582],
#        [2868],
#        [3399],
#        [2660],
#        [2807],
#        [3664],
#        [3102],
#        [2901],
#        [3336],
#        [1950],
#        [2451],
#        [1836],
#        [2542],
#        [3781],
#        [3632],
#        [3613],
#        [4141],
#        [4699],
#        [4457],
#        [4638],
#        [4257],
#        [2219],
#        [1963],
#        [2300],
#        [1649],
#        [2003],
#        [2125],
#        [2108],
#        [2246],
#        [2489],
#        [2391],
#        [2000],
#        [3264],
#        [3459],
#        [3432],
#        [3158],
#        [4668],
#        [4440],
#        [4498],
#        [4657],
#        [3907],
#        [3897],
#        [3730],
#        [3785],
#        [3039],
#        [3221],
#        [3169],
#        [2171],
#        [2639],
#        [2914],
#        [2592],
#        [2702],
#        [2223],
#        [2545],
#        [2984],
#        [1937],
#        [3211],
#        [2694],
#        [2957],
#        [2945],
#        [2671],
#        [1795],
#        [2464],
#        [2220],
#        [2572],
#        [2255],
#        [2202],
#        [4215],
#        [4190],
#        [3962],
#        [4215],
#        [3233],
#        [3353],
#        [3012],
#        [3085],
#        [2035],
#        [2164],
#        [1937],
#        [1795],
#        [3651],
#        [3574],
#        [3645],
#        [3193],
#        [1825],
#        [1990],
#        [2155],
#        [2565],
#        [3150],
#        [3940],
#        [3270],
#        [2930],
#        [3820],
#        [4380],
#        [4055],
#        [3870],
#        [3755],
#        [2045],
#        [2155],
#        [1825],
#        [2300],
#        [1945],
#        [3880],
#        [4060],
#        [4140],
#        [4295],
#        [3520],
#        [3425],
#        [3630],
#        [3525],
#        [4220],
#        [4165],
#        [4325],
#        [4335],
#        [1940],
#        [2740],
#        [2265],
#        [2755],
#        [2051],
#        [2075],
#        [1985],
#        [2190],
#        [2815],
#        [2600],
#        [2720],
#        [1985],
#        [1800],
#        [1985],
#        [2070],
#        [1800],
#        [3365],
#        [3735],
#        [3570],
#        [3535],
#        [3155],
#        [2965],
#        [2720],
#        [3430],
#        [3210],
#        [3380],
#        [3070],
#        [3620],
#        [3410],
#        [3425],
#        [3445],
#        [3205],
#        [4080],
#        [2155],
#        [2560],
#        [2300],
#        [2230],
#        [2515],
#        [2745],
#        [2855],
#        [2405],
#        [2830],
#        [3140],
#        [2795],
#        [3410],
#        [1990],
#        [2135],
#        [3245],
#        [2990],
#        [2890],
#        [3265],
#        [3360],
#        [3840],
#        [3725],
#        [3955],
#        [3830],
#        [4360],
#        [4054],
#        [3605],
#        [3940],
#        [1925],
#        [1975],
#        [1915],
#        [2670],
#        [3530],
#        [3900],
#        [3190],
#        [3420],
#        [2200],
#        [2150],
#        [2020],
#        [2130],
#        [2670],
#        [2595],
#        [2700],
#        [2556],
#        [2144],
#        [1968],
#        [2120],
#        [2019],
#        [2678],
#        [2870],
#        [3003],
#        [3381],
#        [2188],
#        [2711],
#        [2542],
#        [2434],
#        [2265],
#        [2110],
#        [2800],
#        [2110],
#        [2085],
#        [2335],
#        [2950],
#        [3250],
#        [1850],
#        [2145],
#        [1845],
#        [2910],
#        [2420],
#        [2500],
#        [2290],
#        [2490],
#        [2635],
#        [2620],
#        [2725],
#        [2385],
#        [1755],
#        [1875],
#        [1760],
#        [2065],
#        [1975],
#        [2050],
#        [1985],
#        [2215],
#        [2045],
#        [2380],
#        [2190],
#        [2210],
#        [2350],
#        [2615],
#        [2635],
#        [3230],
#        [3160],
#        [2900],
#        [2930],
#        [3415],
#        [3725],
#        [3060],
#        [3465],
#        [2605],
#        [2640],
#        [2395],
#        [2575],
#        [2525],
#        [2735],
#        [2865],
#        [1980],
#        [2025],
#        [1970],
#        [2125],
#        [2125],
#        [2160],
#        [2205],
#        [2245],
#        [1965],
#        [1965],
#        [1995],
#        [2945],
#        [3015],
#        [2585],
#        [2835],
#        [2665],
#        [2370],
#        [2950],
#        [2790],
#        [2130],
#        [2295],
#        [2625],
#        [2720]])

# %%
y.shape
# Out:
# (392, 1)

# %%
""" Multiple Linear Regression """
# k-fold CV (using all the 3 variables) for 5 times
lm = LinearRegression()
# can tune other metrics, such as MSE
scores = cross_val_score(lm, X, y, scoring='neg_mean_squared_error', cv=5)
scores
# Out:
# array([-168066.74726422,  -94144.34580807,  -78223.41445844,
#         -48007.71189022, -116785.90395613])

# %%
""" XGBOOST """
from xgboost import XGBRegressor

my_model = XGBRegressor()
# can tune other metrics, such as MSE
scores = cross_val_score(my_model, X, y, scoring='neg_mean_squared_error', cv=5)
scores
# Out:
# [01:04:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:04:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:04:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:04:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:04:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# array([-186522.5951182 ,  -86182.18667086,  -82654.3741858 ,
#         -34760.41135122,  -43382.35990583])

# %% [markdown]
# In this dataset the two models have different scores , sometimes the negative MSE for XGBRegressor is better than simple linear regression , and other times simple linear regression is better than XGBRegressor
